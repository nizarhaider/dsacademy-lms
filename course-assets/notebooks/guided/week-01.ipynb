# %% [markdown]
# # Week 01: Computational Thinking and Python Basics
#
# This guided notebook assumes **No prior coding knowledge**.
#
# ## Learning outcomes
#
# - Explain algorithms in plain language.
# - Use variables in a small worked example.
# - Complete the guided lab and verify syntax errors.

# %% [markdown]
# ## Concepts before code
#
# - **algorithms**
# - **variables**
# - **expressions**
# - **syntax errors**
#
# ### Core mechanism
#
# An input is stored in variables, transformed by expressions, and displayed as output.
#
# ### Terms and symbols
#
# - `variable`: A named reference to a value.
# - `expression`: Values and operators that produce a result.

# %% [markdown]
# ## Worked example: predict first
#
# Store a course price of 8000 and a 10% discount; calculate and print 7200.
#
# Before running the next cell:
#
# 1. Write the expected output.
# 2. Identify the input values.
# 3. Identify the transformation.
# 4. Explain what the result means.

# %%
price = 8000
discount_rate = 0.10
final_price = price - price * discount_rate
print(final_price)

# %% [markdown]
# ### Check the evidence
#
# Expected reference output:
#
# ```text
# 7200.0
# ```
#
# Verification requirement:
#
# Change the inputs, predict the output first, and confirm Python produces the predicted value.
#
# Do not continue until you can explain why the output has this value or shape.

# %% [markdown]
# ## Build the complete mental model
#
# 1. An algorithm must terminate and produce the same result for the same stated inputs.
# 2. `=` assigns a value; `==` asks whether two values are equal.
# 3. Python evaluates `*` before `+`; parentheses make intended order explicit.
# 4. Read an error from its final line, then inspect the reported file and line number.
#
# ## Common mistakes
#
# - Reading `=` as mathematical equality instead of assignment.
# - Treating an error message as a failure rather than diagnostic evidence.

# %% [markdown]
# ## Guided lab
#
# Write a program that converts study minutes into hours and remaining minutes.
#
# Work in this order:
#
# 1. **Predict** what the next operation should do.
# 2. **Run** the smallest relevant section.
# 3. **Inspect** values, shapes, metrics, or traces.
# 4. **Explain** the observed result in plain language.

# %%
# Guided lab workspace: Week 01
# Add only the imports needed for the current step.

# TODO 1: Prepare the smallest valid input.

# TODO 2: Apply the concept taught in the slides.

# TODO 3: Print or display inspectable intermediate evidence.

# TODO 4: Check the result against the lesson's verification requirement.

# %% [markdown]
# ## Continue into the source notebook
#
# Source notebook:
#
# <https://github.com/curiousily/AI-Bootcamp/blob/master/01.python-essentials-for-ai.ipynb>
#
# Before running each source section, label it as one of:
#
# - input or data preparation
# - transformation or model operation
# - evaluation or verification
# - persistence or deployment
#
# If a source cell uses an unfamiliar API, first identify the concept it implements.

# %% [markdown]
# ## Weekly deliverable
#
# A runnable Python file with named inputs, a calculation, output, and comments explaining each line.
#
# Include:
#
# - your prediction before execution
# - the observed evidence
# - one mistake or failed assumption
# - the correction
# - a plain-language explanation of the final result

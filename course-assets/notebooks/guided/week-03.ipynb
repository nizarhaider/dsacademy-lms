# %% [markdown]
# # Week 03: Data Analysis with NumPy and Pandas
#
# This guided notebook assumes **Python collections, conditions, loops, and functions**.
#
# ## Learning outcomes
#
# - Explain arrays and shapes in plain language.
# - Use DataFrames in a small worked example.
# - Complete the guided lab and verify missing values.

# %% [markdown]
# ## Concepts before code
#
# - **arrays and shapes**
# - **DataFrames**
# - **filtering and grouping**
# - **missing values**
#
# ### Core mechanism
#
# NumPy applies one operation across shaped numerical arrays; Pandas labels rows and columns for tabular analysis.
#
# ### Terms and symbols
#
# - `shape`: The length of every array axis.
# - `row`: One observation.
# - `column`: One measured variable.

# %% [markdown]
# ## Worked example: predict first
#
# Calculate the mean of three scores, then group a four-row table by course.
#
# Before running the next cell:
#
# 1. Write the expected output.
# 2. Identify the input values.
# 3. Identify the transformation.
# 4. Explain what the result means.

# %%
import pandas as pd
df = pd.DataFrame({"course": ["AI", "AI", "Web"], "score": [70, 90, 60]})
print(df.groupby("course")["score"].mean())

# %% [markdown]
# ### Check the evidence
#
# Expected reference output:
#
# ```text
# course
# AI     80.0
# Web    60.0
# ```
#
# Verification requirement:
#
# Report the input and output shapes and independently check one grouped result by hand.
#
# Do not continue until you can explain why the output has this value or shape.

# %% [markdown]
# ## Build the complete mental model
#
# 1. One row must have a declared grain, such as one student, transaction, or day.
# 2. Axis 0 moves down rows; axis 1 moves across columns in a two-dimensional table.
# 3. A boolean mask contains one True/False decision per row and supports transparent filtering.
# 4. Missing values require a reasoned policy: retain, impute, exclude, or collect again.
#
# ## Common mistakes
#
# - Applying an operation along the wrong array or DataFrame axis and misreading the result.
# - Dropping missing rows without explaining what information is lost.

# %% [markdown]
# ## Guided lab
#
# Load a small CSV, inspect its shape, filter valid rows, and calculate grouped summaries.
#
# Work in this order:
#
# 1. **Predict** what the next operation should do.
# 2. **Run** the smallest relevant section.
# 3. **Inspect** values, shapes, metrics, or traces.
# 4. **Explain** the observed result in plain language.

# %%
# Guided lab workspace: Week 03
# Add only the imports needed for the current step.

# TODO 1: Prepare the smallest valid input.

# TODO 2: Apply the concept taught in the slides.

# TODO 3: Print or display inspectable intermediate evidence.

# TODO 4: Check the result against the lesson's verification requirement.

# %% [markdown]
# ## Continue into the source notebook
#
# Source notebook:
#
# <https://github.com/curiousily/AI-Bootcamp/blob/master/01.python-essentials-for-ai.ipynb>
#
# Before running each source section, label it as one of:
#
# - input or data preparation
# - transformation or model operation
# - evaluation or verification
# - persistence or deployment
#
# If a source cell uses an unfamiliar API, first identify the concept it implements.

# %% [markdown]
# ## Weekly deliverable
#
# A notebook that explains row grain, column meanings, filters, missing values, and two grouped results.
#
# Include:
#
# - your prediction before execution
# - the observed evidence
# - one mistake or failed assumption
# - the correction
# - a plain-language explanation of the final result

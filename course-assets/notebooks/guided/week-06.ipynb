# %% [markdown]
# # Week 06: Machine Learning Fundamentals
#
# This guided notebook assumes **Features, targets, tables, distributions, and basic mathematical functions**.
#
# ## Learning outcomes
#
# - Explain supervised and unsupervised learning in plain language.
# - Use regression and classification in a small worked example.
# - Complete the guided lab and verify generalization.

# %% [markdown]
# ## Concepts before code
#
# - **supervised and unsupervised learning**
# - **regression and classification**
# - **training and inference**
# - **generalization**
#
# ### Core mechanism
#
# A model learns a mapping or structure from training data and is judged on unseen examples that represent future use.
#
# ### Terms and symbols
#
# - `feature`: An input available at prediction time.
# - `target`: The value a supervised model learns to predict.
# - `label`: A categorical target.

# %% [markdown]
# ## Worked example: predict first
#
# Classify house price as regression, spam detection as classification, and customer grouping as clustering.
#
# Before running the next cell:
#
# 1. Write the expected output.
# 2. Identify the input values.
# 3. Identify the transformation.
# 4. Explain what the result means.

# %%
problems = {"price": "regression", "spam": "classification", "segments": "clustering"}
for name, kind in problems.items():
    print(name, kind)

# %% [markdown]
# ### Check the evidence
#
# Expected reference output:
#
# ```text
# price regression
# spam classification
# segments clustering
# ```
#
# Verification requirement:
#
# For each problem, verify the target type and explain what one unseen test row represents.
#
# Do not continue until you can explain why the output has this value or shape.

# %% [markdown]
# ## Build the complete mental model
#
# 1. Regression targets are continuous; classification targets are categories; clustering has no supplied target.
# 2. Training learns parameters, validation selects choices, and testing estimates final generalization.
# 3. Underfitting misses structure; overfitting learns training-specific noise.
# 4. Leakage occurs whenever training receives information unavailable at real prediction time.
#
# ## Common mistakes
#
# - Calling every prediction problem classification.
# - Evaluating on rows that influenced training or preprocessing.

# %% [markdown]
# ## Guided lab
#
# Frame five business questions by identifying observation, features, target, learning type, and evaluation evidence.
#
# Work in this order:
#
# 1. **Predict** what the next operation should do.
# 2. **Run** the smallest relevant section.
# 3. **Inspect** values, shapes, metrics, or traces.
# 4. **Explain** the observed result in plain language.

# %%
# Guided lab workspace: Week 06
# Add only the imports needed for the current step.

# TODO 1: Prepare the smallest valid input.

# TODO 2: Apply the concept taught in the slides.

# TODO 3: Print or display inspectable intermediate evidence.

# TODO 4: Check the result against the lesson's verification requirement.

# %% [markdown]
# ## Continue into the source notebook
#
# Source notebook:
#
# <https://github.com/curiousily/AI-Bootcamp/blob/master/03.model-development.ipynb>
#
# Before running each source section, label it as one of:
#
# - input or data preparation
# - transformation or model operation
# - evaluation or verification
# - persistence or deployment
#
# If a source cell uses an unfamiliar API, first identify the concept it implements.

# %% [markdown]
# ## Weekly deliverable
#
# A problem-framing worksheet with justified learning types and train/validation/test boundaries.
#
# Include:
#
# - your prediction before execution
# - the observed evidence
# - one mistake or failed assumption
# - the correction
# - a plain-language explanation of the final result
